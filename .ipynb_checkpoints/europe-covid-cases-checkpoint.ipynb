# %%
import pandas as pd
import os
import numpy

# %%
csv_path = os.path.join("Resources", "europe_covid_cases.csv")

# %%
df = pd.read_csv(csv_path)
df
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     29/04/2021   29      4  2021    2286      29                 Austria
# 1     28/04/2021   28      4  2021    1557      20                 Austria
# 2     27/04/2021   27      4  2021    1380      22                 Austria
# 3     26/04/2021   26      4  2021    2091      11                 Austria
# 4     25/04/2021   25      4  2021    2231      15                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 1795  05/03/2021    5      3  2021    4070      14                  Sweden
# 1796  04/03/2021    4      3  2021    4884      19                  Sweden
# 1797  03/03/2021    3      3  2021    4877      19                  Sweden
# 1798  02/03/2021    2      3  2021    6191      23                  Sweden
# 1799  01/03/2021    1      3  2021  669003   13072                  Sweden
#
#      geoId countryterritoryCode  popData2020 continentExp
# ...
